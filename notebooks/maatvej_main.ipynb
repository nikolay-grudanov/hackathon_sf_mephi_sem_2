# %%
import pandas as pd
import re

# Загрузка данных
data = pd.read_csv('combined.csv', sep=',', header=None, names=['doc_text', 'image2text', 'speech2text'])

# Просмотр первых строк данных
print(data.head())

# Просмотр информации о данных
print(data.info())

# Проверка наличия пропущенных значений
print(data.isnull().sum())
# Out:
#                                             doc_text  \
# 0                                           doc_text
# 1                                           doc_text
# 2  Твой лучший секс спрятан здесь 🔞  Делюсь канал...
# 3  ⭐️  Кнопка: ⭐️START⭐️(https://t.me/major/start...
# 4  А продолжение где? Правильно. В моем сообществ...
#
#                                           image2text  speech2text
# 0                                         image2text  speech2text
# 1                                         image2text  speech2text
# 2                                                NaN          NaN
# 3                                                NaN          NaN
# 4  девчонки не умеют переписываться sanille они э...          NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6007 entries, 0 to 6006
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   doc_text     6007 non-null   object
#  1   image2text   3427 non-null   object
#  2   speech2text  1878 non-null   object
# dtypes: object(3)
# memory usage: 140.9+ KB
# None
# doc_text          0
# image2text     2580
# speech2text    4129
# dtype: int64

# %%
# Заполнение пропущенных значений пустыми строками
data = data.fillna('')

# Проверка наличия дубликатов
print(data.duplicated().sum())

# Удаление дубликатов
data = data.drop_duplicates()

# Функция для очистки текста
def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)  # Удаление пунктуации
    text = re.sub(r'\s+', ' ', text)  # Удаление лишних пробелов
    return text


# Очистка текста в каждой колонке
data['doc_text'] = data['doc_text'].apply(clean_text)
data['image2text'] = data['image2text'].apply(clean_text)
data['speech2text'] = data['speech2text'].apply(clean_text)

# Сохранение предобработанных данных
data.to_csv('combined_cleaned.csv', index=False, sep=',')
# Out:
# 386

# %%
# Анализ уникальных значений в каждом столбце
for col in data.columns:
    unique_values = data[col].unique()
    print(f"Column {col}:")
    print(unique_values[:10])  # Показываем первые 10 уникальных значений для краткости
    print("\n")
# Out:
# Column doc_text:
# ['doc_text'
#  'твой лучший секс спрятан здесь делюсь каналом дипломированного сексолога крис взломала код классного секса мастерски раскрепощает знает миллион горячих техник и лучшие девайсы для взрослых самые полезные посты здесь отрезвляющий пост я все сама прокачай наездницу ролевая игра vip кинотеатр техника оральных ласк как занимается сeксом неудобная женщина кстати крис провела трехдневный безоплатный онлайн интенсивот бревна до богини совместно с врачом и владельцем сексшопа скорее смотри записи пока не удалила httpstmesekretskris1048 здесь жарче чем в аду '
#  ' кнопка starthttpstmemajorstartstartapp1972869792'
#  'а продолжение где правильно в моем сообществе в вк ссылка в шапке профиля'
#  'тем временем моя авторская телега уверенно в тройке сильнейших компания мощная ухххх '
#  'у меня есть двоюродная сестра у нее есть сын антон мой двоюродный племянник получается он снимает свой подкаст конечно я пришла его поддержать получилось честное и откровенное интервью смотрите httpsyoutubeaifyxpjaa1qsimh4_bwskrakkcmv'
#  'мои ученики ко мне возвращаются мои волшебные вы не представляете насколько круто и приятно когда мои ученики с других курсов и потоков вновь возвращаются ко мне на обучение и тем более под мое наставничество главное преимущество виптарифа это мое чуткое руководство я вам подскажу направлю и помогу хотите начать путь в мир эзотерики и мантики с опытным наставником тогда жду вас на собеседовании переходите по ссылке и записывайтесь httpswame79043358533'
#  'на ютюб канале olympics эти дни и сейчас идут прямые трансляции соревнований проверяла без vpn видимо там и церемонию открытия покажут вот ссылка нужно выбрать вкладку трансляции httpsyoutubecomolympicssidx1tervagjgayeto п olympics welcome to the olympics youtube channel where the games never end from the best musical moments at the olympic games in our music monday series to weekly compilation videos with highlights from the olympics on fridays plus exclusive documentaries about the stories behind the glory this is where you can find everything about the biggest sporting event in the world httpsyoutubecomolympicssidx1tervagjgayeto'
#  'смотреть httpsyoutubeepu_3sy7os п раздевалка 12 сергей орлов и александр пташенчук баскетбол или бацкетбол вам сюда httpsmediumsportru как правильно произносить название нашей любимой игры баскетбол или бацкетбол у сереги орлова есть своя версия смотри выпуск раздевалки и узнаешь как верный ответ дада саша пташенчук тоже был в шоке наш тг httpstmemediumbasket хочешь смотреть больше баскетбольных видео инсайды бэкстейджы и не вошедшее будет на канале medium basket shorts подписывайся mediumbasketshorts httpsyoutubeepu_3sy7os'
#  'сегодня день рождения матвея кисляка и этот выпуск молодого подкаста мы готовили как подарок юному армейцу ровно год назад он дебютировал за цска и забил первый гол а теперь он свободно рассуждает о жизни о гвардиоле и кройфе и точно знает что хотел бы стать тренером а ведь ему только что исполнилось 19 лет клик чтобы получить удовольствие от взрослого разговора с юношей абсолютное открытие httpsyoutubev4ywwqjkgm8sibp4zt4z4zj2m7y3l п кисляк матч против матеуса игры в бразилии и мечта стать тренером молодой подкаст 2 матвей кисляк рассказал эду и нагучеву про свою футбольную карьеру второй выпуск молодого подкаста с восходящей звездой цска детство в старом осколе и соседство с емельяненко матч против легенд футбола перед стартом чм2018 посещение футбольного места силы в бразилии телега нагучева httpstmeoffearth телега эда httpstmeededik ютубканал эда httpswwwyoutubecomedams19 следите за юфл и мфл в наших соцсетях и на сайте сайт httpsyflrussiaru юфл в вк а также обзоры интервью и записи игр тут httpsvkcomyflrussia мфл в вк а также обзоры интервью и записи игр тут httpsvkcommflrussia telegram юфл httpstmeyflrussia telegram мфл httpstmemflrussia дзен httpsdzenruyfl httpsyoutubev4ywwqjkgm8sibp4zt4z4zj2m7y3l']
#
#
# Column image2text:
# ['image2text' ''
#  'девчонки не умеют переписываться sanille они это очень любят но категорически не умеют strilp'
#  '1042 nuil пул telegram 51 142 подписчика 12 9607 авторские 1 маргарита симоньян 2 соловьёв 3 реальный губер 4 павел островский 5 захар прилепин 6 поддубный 7 мария захарова 8 ирина волк 9 неофициальный безсонов 10 анастасия кашеварова 11 андрей медведев 12 небожена 13 дмитрий медведев 14 kotsnews 15 валентина матвиенко 16 алёна бердова 17 лера кудрявцева 18 abbas djuma 19 доктор сосновский 20 zergulio 21 media малькевич 22 александр хинштейн 23 юрий баранчик 24 президент гордон 25 ляйсан утяшева 26 екатерина мизулина 27 не последние люди в городе 28 вячеслав володин 29 парфентьев клуб вкл звук'
#  'т с не е z 8 8 ничего не знала о стендапе маргарита родина'
#  '1042 ul пул telegram 51 142 подписчика 129607 авторские 1 маргарита симоньян 2 соловьёв 3 реальный губер 4 павел островский 5 захар прилепин 6 поддубный 7 мария захарова 8 ирина волк 9 неофициальный безсонов 10 анастасия кашеварова 11 андрей медведев 12 небожена 13 дмитрий медведев 14 kotsnews 15 валентина матвиенко 16 алёна бердова 17 лера кудрявцева 18 abbas djuma 19 доктор сосновский 20 zergulio 21 media малькевич 22 александр хинштейн 23 юрий баранчик 24 президент гордон 25 ляйсан утяшева 26 екатерина мизулина 27 не последние люди в городе 28 вячеслав володин 29 парфентьевклуб вкл звук'
#  'л лера обучалась таро у алексея по вип тарифу сейчас прошла собеседование по ленорман хочу сказать что алексей действительно очень прекрасный и чуткий наставник курс по таро к примеру у меня окупился в течение месяца поэтому вообще не жалейте идите на курс 1348'
#  'пташенчук раздевалка орлов звёзды х'
#  'цско 78 и 7 матвей киспяк мополои поскаст' 'масик это ']
#
#
# Column speech2text:
# ['speech2text' ''
#  'масик это нееба а какая карта будет подсказывать современное значение масик штрих скуф давай попробуем кто у нас первый давай начнем с масика кто это у нас масик это классный здоровый адекватный парень который готов к отношениям к развитию то есть короче в норме он нееба да тогда в оракуле ленорман масика будет символизировать карта мужчины в картах второго масик это император четвертый старший аркадий ну или любой из королей'
#  'моя волшебная всем привет желаю прекрасного дня и давайте начнем его с вашей самой любимой рубрики конечно же с карты дня мои волшебные всем привет ну что давайте заглянем в карту сегодняшнего дня и это тройка жезлов подробное описание которой я уже разместил в своем официальном телеграм канале по ссылке в этой истории'
#  'меня зовут юлиана я из москвы как вы познакомились с алексеем как давно это было мне кажется года 4 5 назад просто в инстаграме увидела в ленте зашла на инстаграм увидела что он там пишет подписалась потом зашла на сайт торо помоему с нуля было и я пошла на этот курс и после этого всё надолго прекрасно а подскажите вы помимо торо какието ещё курсы проходили да проходила ленарман метафорические карты всё такое а как вообще изучение курсов повлияло на вашу жизнь может быть деньги отношения ещё чтото есть какието изменения да колоссальные вообще я зашла изза того что алексей психолог сам по образованию я тоже психолог и когда я посмотрела с точки зрения психологии послушала что он говорит я очень обожаю юнга и если бы не было этого если бы не было у него профессионального образования возможно я бы вообще не зашла туда я зашла и влюбилась в карты и в моей жизни благодаря алексею я была у него на очных встречах и мы так общались очень колоссально много вообще что в моей жизни поменялось и в плане денег я вышла на более уровень заработной платы и карьеры и личной жизни ну я не знаю это можно бесконечно говорить и там в отношениях с семьёй с родителями с сыном ну всё благодаря только лёше'
#  'всем привет это большой интерконтинентальный межгалактический турнир roast battle label comp что мы сделали мы позвали классных крутых комиков которые весь сезон будут бороться за самый большой денежный приз в истории проекта'
#  'ты нас убъёшь это как заразит она ты ещё первый этаж спустишь я вам дам самую мощную подсказку блин серёжка серёжка подожди серёжка сядь нормально сядь нормально'
#  'вопервых он понимал что мне некуда идти у меня нет родственников и соответственно он мне всегда говорил куда ты пойдёшь ты никому не нужна меня это вбивал и меня это конечно тоже вводило в депрессию тогда и один раз я получается вскрыла себе вены изза него вскрыть вены было в тот момент проще чем уйти мне некуда было идти мне было некуда идти на планете земля я просто думала что я не смогу выжить мне некуда было идти когда он мне сказал фразу что я тебя не любил живу с тобой изза детей и ты никогда никому не будешь нужна я переключилась тогда это сейчас я понимаю я тогда переключилась на своих родителей и тогда когда я это ощутила я испытала это чувство что я вообще этому миру не нужна и просто мне нужно уйти с этого пути и не жить а зачем жить когда тебе больно'
#  'а ты чувствуешь кстати вот в дк что люди пьяные какимто образом ну их обычно человек спрашивает на разыгрывании типа кто до этого выпил один раз один раз мне выкрикнули помоему один раз ну и то там знаешь типа был такой когда я чтото выступаю и мне выкрик я услышал момент типа салам алейкум вот такое то есть я очень рад что я еще такой комик что как бы меня это все не убивает знаешь я знаю что есть люди которые выкрикнули и они у них инсульт случается и такие нет это сейчас это крутая ситуация когда он типа раз и остыл'
#  'мои волшебные всем привет желаю прекрасного дня и давайте начнем его с вашей самой любимой рубрики конечно же с карты дня мои волшебные всем привет давайте посмотрим какая карта будет картой сегодняшнего дня и это туз мичей что это означает узнать очень легко просто переходите по ссылке в этой сторис на мой официальный телеграмканал и читайте новый пост про карты дня']

# %%
# Анализ длины текстовых сообщений
data['doc_text_length'] = data['doc_text'].apply(len)
data['image2text_length'] = data['image2text'].apply(len)
data['speech2text_length'] = data['speech2text'].apply(len)

print(data[['doc_text_length', 'image2text_length', 'speech2text_length']].describe())
# Out:
#        doc_text_length  image2text_length  speech2text_length
# count      5621.000000        5621.000000         5621.000000
# mean        351.081124          43.971891          146.808397
# std         505.396713         152.411631          326.140214
# min           0.000000           0.000000            0.000000
# 25%          66.000000           0.000000            0.000000
# 50%         163.000000           3.000000            0.000000
# 75%         433.000000          34.000000          110.000000
# max        7709.000000        5099.000000         5119.000000

# %%
from collections import Counter

# Функция для подсчета частоты слов
def count_words(text):
    words = text.split()
    return Counter(words)

# Подсчет частоты слов в каждой колонке
doc_word_counts = Counter(" ".join(data['doc_text']).split())
image_word_counts = Counter(" ".join(data['image2text']).split())
speech_word_counts = Counter(" ".join(data['speech2text']).split())

# Наиболее часто встречающиеся слова
most_common_doc_words = doc_word_counts.most_common(10)
most_common_image_words = image_word_counts.most_common(10)
most_common_speech_words = speech_word_counts.most_common(10)

print("Наиболее часто встречающиеся слова в doc_text:")
print(most_common_doc_words)

print("\nНаиболее часто встречающиеся слова в image2text:")
print(most_common_image_words)

print("\nНаиболее часто встречающиеся слова в speech2text:")
print(most_common_speech_words)
# Out:
# Наиболее часто встречающиеся слова в doc_text:
# [('в', 9854), ('и', 8751), ('на', 5858), ('не', 3708), ('с', 3412), ('что', 2836), ('а', 1980), ('это', 1951), ('по', 1758), ('я', 1736)]
#
# Наиболее часто встречающиеся слова в image2text:
# [('в', 833), ('1', 531), ('и', 512), ('о', 452), ('на', 433), ('2', 353), ('с', 341), ('я', 281), ('а', 259), ('не', 243)]
#
# Наиболее часто встречающиеся слова в speech2text:
# [('я', 3859), ('в', 3791), ('и', 3718), ('не', 2944), ('что', 2640), ('это', 2368), ('на', 2018), ('вот', 1521), ('а', 1474), ('с', 1456)]
